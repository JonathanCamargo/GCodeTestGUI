# %%
from gcodes import *
import matplotlib.pyplot as plt

points=np.array([[0,0],[1,1],[2,2]])
trajectory2gcode(points)
# Out:
# 'G01 X0.00 Y0.00\nG01 X1.00 Y1.00\nG01 X2.00 Y2.00'

# %%
points=patternCreator('s')
plt.plot(points[:,0],points[:,1])

# %%
points=createPattern(xmax=300,xmin=-100,ang_deg=45)
plt.plot(points[:,0],points[:,1])

# %%
gcode=trajectory2gcode(points)
gcode
# Out:
# 'G01 X98.69 Y-1.41\nG01 X-111.83 Y48.59\nG01 X98.69 Y98.59\nG01 X288.17 Y53.59\nG01 X98.69 Y8.59\nG01 X98.69 Y8.59\nG01 X-69.73 Y48.59\nG01 X98.69 Y88.59\nG01 X250.27 Y52.59\nG01 X98.69 Y16.59\nG01 X98.69 Y16.59\nG01 X-36.04 Y48.59\nG01 X98.69 Y80.59\nG01 X219.96 Y51.79\nG01 X98.69 Y22.99\nG01 X98.69 Y22.99\nG01 X-9.10 Y48.59\nG01 X98.69 Y74.19\nG01 X195.70 Y51.15\nG01 X98.69 Y28.11\nG01 X98.69 Y28.11\nG01 X12.46 Y48.59\nG01 X98.69 Y69.07\nG01 X176.30 Y50.63\nG01 X98.69 Y32.20\nG01 X98.69 Y32.20\nG01 X29.71 Y48.59\nG01 X98.69 Y64.97\nG01 X160.78 Y50.22\nG01 X98.69 Y35.48\nG01 X98.69 Y35.48\nG01 X43.50 Y48.59\nG01 X98.69 Y61.69\nG01 X148.36 Y49.90\nG01 X98.69 Y38.10'

# %%
import serial.tools.list_ports
ports = serial.tools.list_ports.comports()
sorted(ports)
# Out:
# [<serial.tools.list_ports_common.ListPortInfo at 0x14fb2e515a0>,
#  <serial.tools.list_ports_common.ListPortInfo at 0x14fb3323430>,
#  <serial.tools.list_ports_common.ListPortInfo at 0x14fb3322c50>,
#  <serial.tools.list_ports_common.ListPortInfo at 0x14fb2e51e10>]

# %%
gcode.split('\n')
# Out:
# ['G01 X98.69 Y-1.41',
#  'G01 X-111.83 Y48.59',
#  'G01 X98.69 Y98.59',
#  'G01 X288.17 Y53.59',
#  'G01 X98.69 Y8.59',
#  'G01 X98.69 Y8.59',
#  'G01 X-69.73 Y48.59',
#  'G01 X98.69 Y88.59',
#  'G01 X250.27 Y52.59',
#  'G01 X98.69 Y16.59',
#  'G01 X98.69 Y16.59',
#  'G01 X-36.04 Y48.59',
#  'G01 X98.69 Y80.59',
#  'G01 X219.96 Y51.79',
#  'G01 X98.69 Y22.99',
#  'G01 X98.69 Y22.99',
#  'G01 X-9.10 Y48.59',
#  'G01 X98.69 Y74.19',
#  'G01 X195.70 Y51.15',
#  'G01 X98.69 Y28.11',
#  'G01 X98.69 Y28.11',
#  'G01 X12.46 Y48.59',
#  'G01 X98.69 Y69.07',
#  'G01 X176.30 Y50.63',
#  'G01 X98.69 Y32.20',
#  'G01 X98.69 Y32.20',
#  'G01 X29.71 Y48.59',
#  'G01 X98.69 Y64.97',
#  'G01 X160.78 Y50.22',
#  'G01 X98.69 Y35.48',
#  'G01 X98.69 Y35.48',
#  'G01 X43.50 Y48.59',
#  'G01 X98.69 Y61.69',
#  'G01 X148.36 Y49.90',
#  'G01 X98.69 Y38.10']
